# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# <h1>Data Science Tools and Ecosystem</h1>

# %% [markdown]
# <h1>In this notebook, Data Science Tools and Ecosystem are summarized.</h1>

# %% [markdown]
# <p><strong>Objectives:</strong></p>
# <ul>
#   <li>List popular languages for Data Science.</li>
#   <li>Introduce key libraries for Data Science in Python and R.</li>
#   <li>Explain the importance of version control systems like Git for collaboration.</li>
#   <li>Demonstrate basic data manipulation and visualization techniques.</li>
# </ul>

# %% [markdown]
# <h2>Author</h2>
# <p>Nandita</p>

# %% [markdown]
# Some of the popular languages that Data Scientists use are:
# <ol>
#   <li>python</li>
#   <li>R</li>
#   <li>Julia</li>
# </ol>

# %% [markdown]
# <p>Some of the commonly used libraries used by Data Scientists include:</p>
# <ol>
#   <li>numpy</li>
#   <li>tensorflow</li>
#   <li>pandas</li>
# </ol>

# %% [markdown]
# <table>
#   <tr>
#     <th>Data Science Tools</th>
#   </tr>
#   <tr>
#     <td>Jupyter Notebook</td>
#   </tr>
#   <tr>
#     <td>RStudio</td>
#   </tr>
#   <tr>
#     <td>Apache Zeppelin</td>
#   </tr>
# </table>

# %% [markdown]
# <h3>Below are a few examples of evaluating arithmetic expressions in Python</h3>

# %%
# This a simple arithmetic expression to mutiply then add integers.
(3*4)+5
# Out:
# Running cells with 'c:\Users\nandi\AppData\Local\Programs\Python\Python311\python.exe' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'c:/Users/nandi/AppData/Local/Programs/Python/Python311/python.exe -m pip install ipykernel -U --user --force-reinstall'

# %%
# This will convert 200 minutes to hours by diving by 60.
minutes = 330 % 60
hours = 330 // 60
